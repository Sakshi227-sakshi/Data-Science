# %% [markdown]
# <a href="https://colab.research.google.com/github/Sakshi227-sakshi/Data-Science/blob/main/1_Python_Fundamentals.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #1. Python Output

# %%
#Python is a case sensitive language
print('Hello World')
# Out:
# Hello World

# %%
print('Sakshi')
# Out:
# Sakshi

# %%
print(7)
# Out:
# 7

# %%
print(True)
# Out:
# True

# %%
print('hello',1,4.5,True)
# Out:
# hello 1 4.5 True

# %%
print('HEloo',1,4.5,True,sep='/')
# Out:
# HEloo/1/4.5/True

# %%
print('sakshi')
print('haldkar')
# Out:
# sakshi
# haldkar

# %%
print('sakshi',end='-')
print('haldkar')
# Out:
# sakshi-haldkar

# %% [markdown]
# #2.Data Types

# %%
#Integers
print(8)
print(1e309)
# Out:
# 8
# inf

# %%
#Decimal/Flot
print(8.55)
print(1.7e309)
# Out:
# 8.55
# inf

# %%
#Boolean
print(True)
print(False)
# Out:
# True
# False

# %%
#Text/String
print('Hello World')
# Out:
# Hello World

# %%
#complex
print(5+6j)
# Out:
# (5+6j)

# %%
#list-> c-> Arry
print([1,2,3,4,5])
# Out:
# [1, 2, 3, 4, 5]

# %%
#Tuple
print((1,2,3,4,5))
# Out:
# (1, 2, 3, 4, 5)

# %%
#sets
print({1,2,3,4,5})
# Out:
# {1, 2, 3, 4, 5}

# %%
#Dictionary
print({'name':'Sakshi','Gender':'Female','Weight':40})
# Out:
# {'name': 'Sakshi', 'Gender': 'Female', 'Weight': 40}

# %%
#type
type([1,2,3,4,5])
# Out:
# list

# %% [markdown]
# #3.Variables

# %%
#Satatic Vs Dynamic Typing
#Static Vs Dynamic Binding
#stylish declaration techniques

# %%
from os import name
#C/C++
name = 'Sakshi'
print(name)

a= 5
b= 6

print(a + b)
# Out:
# Sakshi
# 11

# %%
#Dynamic Typing.....not read data type ...python
a = 5

#static Typing..c cpp java
int a = 5

# %%
#Dynamic Binding........ Data type fix nhi hota
# kisi bhi data type ko hold kar sakta hai
a = 5
print(a)

a= 'sakshi'
print(a)

#static Binding C cpp java
int a = 5
# Out:
# 5
# sakshi

# %%
a = 1
b = 2
c = 3
print(a,b,c)
# Out:
# 1 2 3

# %%
a,b,c=1,2,3
print(a,b,c)
# Out:
# 1 2 3

# %%
a=b=c=5
print(a,b,c)
# Out:
# 5 5 5

# %% [markdown]
# **Comments**

# %%
#this i sa comment
a= 2
b= 3
#second comment
print(a+b)
# Out:
# 5

# %% [markdown]
# #4.Keywords & Identifires

# %%
#Keywords

# %%
#Identifiers
#You can't start with a digit
name1 = 'sakshi'
print(name1)

#You can use special chars -> _ (uderscore)
_ = 'sakshi'
print(_)

#identifiers can not be keywords
# Out:
# sakshi
# sakshi

# %% [markdown]
# #5.User Input

# %%
#Static Vs Dynamic
input ('Enter name ')
# Out:
# Enter name Sakshi haldkar
# 'Sakshi haldkar'

# %%
#take input from users and store them in a variables
#fnum = input('enter first number')
#snum = input('enter second number')....string type print krega

fnum = int(input('enter first number'))
snum = int(input('enter second number'))#....integer type print karega

#print(type(fnum),type(snum))
#add the 2 value
result = int(fnum) + int(snum)
#print the result
print(result)
print(type(fnum))
# Out:
# enter first number56
# enter second number67
# 123
# <class 'int'>

# %% [markdown]
# #6.Type Conversion

# %%
#Implicit Vs Explicit
print(5+5.6)
print(type(5),type (5.6))

#print(4+'4')
# Out:
# 10.6
# <class 'int'> <class 'float'>

# %%
#Explicit
#str -> int
type(int('4'))
#int(4.5)
#int(4+5j)
# Out:
# int

# %%
#int to str
str(5)
# Out:
# '5'

# %%
#float
float(4)
# Out:
# 4.0

# %% [markdown]
# #7.Literals

# %%
#variable ke ander jo raw value store karta hai
a = 0b1010#Binary Literals
b = 100 #Decimal Literal
c = 0o310 #octel literal
d = 0x12c #HexaDecimal literal

#Float Literal
float_1 = 10.5
float_2 = 1.5e2 #1.5 * 10^2
float_3 = 1.5e-3 #1.5 * 10^-3

#Complex Literal
x = 3.14j

print(a,b,c,d)
print(float_1, float_2,float_3)
print(x, x.img, x.real)

# %%
#binary
x= 3.14j
print(x.imag)
# Out:
# 3.14

# %%
#binary
a = 0b1010
print(a)
# Out:
# 10

# %%
 #octel literal
 c = 0o310
 print(c)
# Out:
# 200

# %%
#binary
c = 0o310
print(1.5e3)
# Out:
# 1500.0

# %%
string = 'This is python'
strings = "This is python"
char = "C"
multiline_str = """ This is a multiline string with more then one line code."""
unicode = u"\U0001f600\U0001F606\U0001F923"
raw_str = r"raw \n string"

print(string)
print(strings)
print(char)
print(multiline_str)
print(unicode)
print(raw_str)
# Out:
# This is python
# This is python
# C
#  This is a multiline string with more then one line code.
# 😀😆🤣
# raw \n string

# %%
a = True +4
b = False + 10

print("a:",a)
print("b:",b)
# Out:
# a: 5
# b: 10

# %%
a = None
print(a)
# Out:
# None

# %%
k = None
a = 5
b = 6
print('Pogram exe')
# Out:
# Pogram exe
