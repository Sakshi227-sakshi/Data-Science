# %% [markdown]
# <a href="https://colab.research.google.com/github/Sakshi227-sakshi/Data-Science/blob/main/8_OOP_Part_2_Encapsulation_%26_Static_Keyword.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Write OOP classes to handle the following scenarios:
# * A user can create and view 2D coordinates
# * A user can find out the distence between 2 coordinates
# * A user can find the distance of a coordinate from origin
# * A user can check if a point lies on a given line
# * A user can find the distance between a given 2D point and given line

# %%
class Point:

  def __init__(self, x, y):
    self.x_cod = x
    self.y_cod = y

  def __str__(self):
    return '<{},{}>'.format(self.x_cod, self.y_cod)

  def euclidean_distance(self, other):
    return ((self.x_cod - other.x_cod)**2 + (self.y_cod - other.y_cod)**2)**0.5

  def distance_from_origin(self):
    #return self.x_cod**2 +
    return self.euclidean_distance(Point(0,0))

class Line:

  def __init__(self, A, B, C):
    self.A = A
    self.B = B
    self.C = C

  def __str__(self):
    return '{}x + {}y + {} = 0'.format(self.A, self.B, self.C)

  def point_on_line(line, point):
    if line.A*point.x_cod + line.B*point.y_cod + line.C == 0:
      return "lies on the line"
    else:
      return "does not lie on the line"

  def shortest_distence(line, point):
   return abs(line.A*point.x_cod + line.B*point.y_cod + line.C)/(line.A**2 + line.B**2)**0.5

# %%
p1 = Point(3, 4)
p2 = Point(5, 6)
# <x,y>
print(p1)
print(p2)

p1.euclidean_distance(p2)
#
#p1.distance_from_origin()
# Out:
# <3,4>
# <5,6>
# 2.8284271247461903

# %%
l1 = Line(1, 2, 3)
print(l1)
# Out:
# 1x + 2y + 3 = 0

# %%
l1 = Line(1, 2, -3)
p1 = Point(1,10)
print(l1)
print(p1)

l1.point_on_line(p1)
# Out:
# 1x + 2y + -3 = 0
# <1,10>
# 'does not lie on the line'

# %%
l1.shortest_distence(p1)
# Out:
# 8.049844718999243

# %% [markdown]
# #How object access attributes

# %%
class Person:
  def __init__(self, name_input, country_input):
    self.name = name_input
    self.country = country_input

  def greet(self):
    if self.country == 'india':
      print('Namaste', self.name)
    else:
      print('Hello', self.name)

# %%
#how to access attributes
p = Person('sakshi','india')

# %%
p.country
# Out:
# 'india'

# %%
p.name
# Out:
# 'sakshi'

# %%
#how ro access method
p.greet()
# Out:
# Namaste sakshi

# %%
# what if i try to access non-existent attribute
p.gender
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipykernel_1921/2510364329.py in <cell line: 0>()
#       1 # what if i try to access non-existent attribute
# ----> 2 p.gender
#
# AttributeError: 'Person' object has no attribute 'gender'

# %% [markdown]
# Attribute creation from outside of the class

# %%
p.gender ='female'

# %%
p.gender
# Out:
# 'female'

# %% [markdown]
# #Reference Variable
# * Reference variable hold the object
# * We can create object without reference variable as well
# * An object can have multiple reference variables
# * Assigning a new reference variable to an existing object does not create a new object

# %%
# object without a reference
class Person:

  def __init__(self):
    self.name = 'sakshi'
    self.gender = 'female'

p = Person()
q = p

# %%
# multiple reference
print(id(p))
print(id(q))
# Out:
# 140484682782032
# 140484682782032

# %%
# Change attribute value eith the help of 2nd object

# %%
print(p.name)
print(q.name)
q.name = 'sakshi2'
print(q.name)
print(p.name)
# Out:
# sakshi
# sakshi
# sakshi2
# sakshi2

# %% [markdown]
# #Pass By reference

# %%
class Person:

  def __init__(self, name, gender):
    self.name = name
    self.gender = gender

# outside the class -> function
def greet(person):
  print('Hi my name is', person.name, 'and I am a', person.gender)
  p1 = Person('neha', 'female')
  return p1

p = Person('sakshi', 'female')
x = greet(p)
print(x.name)
print(x.gender)
# Out:
# Hi my name is sakshi and I am a female
# neha
# female

# %%
class Person:

  def __init__(self, name, gender):
    self.name = name
    self.gender = gender

# outside the class -> function
def greet(person):
  print(id(person))
  print('Hi my name is', person.name, 'and I am a', person.gender)


p = Person('sakshi', 'female')
print(id(p))
greet(p)
# Out:
# 140405435639968
# 140405435639968
# Hi my name is sakshi and I am a female

# %%
class Person:

  def __init__(self, name, gender):
    self.name = name
    self.gender = gender

# outside the class -> function
def greet(person):
  print(id(person))
  person.name = 'ankit'
  print(person.name)


p = Person('sakshi', 'female')
print(id(p))
greet(p)
print(p.name)
# Out:
# 140405220801088
# 140405220801088
# ankit
# ankit

# %%
class Person:

  def __init__(self, name, gender):
    self.name = name
    self.gender = gender

# outside the class -> function
def greet(person):
  person.name = 'ankit'
  return person

p = Person('sakshi', 'female')
print(id(p))
p1 = greet(p)
print(id(p1))
# Out:
# 132156219388992
# 132156219388992

# %% [markdown]
# # Object ki mutability

# %%
class Person:

  def __init__(self, name, gender):
    self.name = name
    self.gender = gender

# outside the class -> function
def greet(person):
  person.name = 'ankit'
  return person

p = Person('sakshi', 'female')
print(id(p))
p1 = greet(p)
print(id(p1))
# Out:
# 136158245688656
# 136158245688656

# %% [markdown]
# #Encapsulation

# %%
#instance var -> python tutor
class Person:

  def __init__ (self,name_input,country_input):
    self.name = name_input
    self.country = country_input

p1 = Person('nitish','india')
p2 = Person('ram','australiya')

# %%
p2.name
# Out:
# 'ram'

# %%
class Atm:

  #constructor(special function) -> superpower ->
  def __init__(self):
    print(id(self))
    self.pin = ''
    self.__balance = 0
    #self.menu()

  def __menu(self):
    user_input = input("""
    Hi how can I help you?
    1. Press 1 to create pin
    2. Press 2 to change pin
    3. Press 3 to check balance
    4. Press 4 to withdraw
    5. Anything else to exit
    """)
    if user_input == '1':
      self.create_pin()
    elif user_input == '2':
      self.change_pin()
    elif user_input == '3':
      self.check_balance()
    elif user_input == '4':
      self.withdraw()
    else:
      exit()

  def create_pin(self):
    user_pin = input('enter your pin')
    self.pin = user_pin

    user_balance = int(input('enter balance'))
    self.__balance = user_balance

    print('pin created successfully')

def change_pin(self):
  old_pin = input('enter old pin')

  if old_pin == self.pin:
    # let him change the pin
    new_pin = input('enter new pin')
    self.pin = new_pin
    print('pin change successful')

  else:
    print('nai karne de sakta re baba')


def check_balance(self):
  user_pin = input('enter your pin')
  if user_pin == self.pin:
    print('your balance is',self.__balace)
  else:
    print('chal nikal yaha se')

def withdraw(self):
  user_pin = input('enter the pin')
  if user_pin == self.pin:
    #allow to withdraw
    amount = int(input('enter the amount'))
    if amount <= self.__balance:
      self.__balance = self.__balance - amount
      print('withdrawl successful.balace is' , self.__balance)
    else:
      print('chal garib')
  else:
     print('sale chor')

# %%
obj = Atm()
# Out:
# 136158209131872

# %%
obj.create_pin()
obj.__Atm__balance = 'hehehe'
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_1022/2749480085.py in <cell line: 0>()
# ----> 1 obj.create_pin()
#       2 obj.__Atm__balance = 'hehehe'
#
# NameError: name 'obj' is not defined

# %%
#obj.balance = 'hehehe'

# %%
#obj.create_pin()
#obj.balance = 'hehehe'

# %%
obj.withdraw()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_1022/3797629794.py in <cell line: 0>()
# ----> 1 obj.withdraw()
#
# NameError: name 'obj' is not defined

# %% [markdown]
# Getter = Private ka value bahar dikahan
#
# Setter = Private ka value bahar se change karna

# %%
class Atm:

  #constructor(special function) -> superpower ->
  def __init__(self):
    print(id(self))
    self.pin = ''
    self.__balance = 0
    #self.menu()

  def get_balance(self):
    return self.__balance

  def set_balance(self,new_value):
    if type(new_value) == int:
      self.__balance = new_value
    else:
      print('beta bahot maarenge')

  def __menu(self):
    user_input = input("""
    Hi how can I help you?
    1. Press 1 to create pin
    2. Press 2 to change pin
    3. Press 3 to check balance
    4. Press 4 to withdraw
    5. Anything else to exit
    """)
    if user_input == '1':
      self.create_pin()
    elif user_input == '2':
      self.change_pin()
    elif user_input == '3':
      self.check_balance()
    elif user_input == '4':
      self.withdraw()
    else:
      exit()

  def create_pin(self):
    user_pin = input('enter your pin')
    self.pin = user_pin

    user_balance = int(input('enter balance'))
    self.__balance = user_balance

    print('pin created successfully')

  def change_pin(self):
    old_pin = input('enter old pin')

    if old_pin == self.pin:
      # let him change the pin
      new_pin = input('enter new pin')
      self.pin = new_pin
      print('pin change successful')

    else:
      print('nai karne de sakta re baba')


  def check_balance(self):
    user_pin = input('enter your pin')
    if user_pin == self.pin:
      print('your balance is',self.__balance)
    else:
      print('chal nikal yaha se')

  def withdraw(self):
    user_pin = input('enter the pin')
    if user_pin == self.pin:
      #allow to withdraw
      amount = int(input('enter the amount'))
      if amount <= self.__balance:
        self.__balance = self.__balance - amount
        print('withdrawl successful.balace is' , self.__balance)
      else:
        print('chal garib')
    else:
       print('sale chor')

# %%
obj = Atm()
# Out:
# 140489909381952

# %%
obj.get_balance()
# Out:
# 0

# %%
obj.set_balance(1000)

# %%
obj.withdraw()
# Out:
# enter the pin1234
# sale chor

# %% [markdown]
# #Collection of object

# %%
# list of objects
class Person:

  def __init__(self, name, gender):
    self.name = name
    self.gender = gender

p1 = Person('sakshi','female')
p2 = Person('krishna','male')
p3 = Person('krish','male')

L = [p1, p2, p3]

for i in L:
  print(i.name, i.gender)
# Out:
# sakshi female
# krishna male
# krish male

# %%
# dict of object

class Person:

  def __init__(self, name, gender):
    self.name = name
    self.gender = gender

p1 = Person('sakshi','female')
p2 = Person('krishna','male')
p3 = Person('krish','male')

L = {'p1':p1,'p2':p2,'p3':p3}

for i in L:
  print(L[i].name, L[i].gender)
# Out:
# sakshi female
# krishna male
# krish male

# %% [markdown]
# # Static Variables(Vs Instance variables)

# %%
class Atm:

  #constructor(special function) -> superpower ->
  def __init__(self):
    print(id(self))
    self.pin = ''
    self.__balance = 0
    self.cid = 0
    self.cid+=1
    #self.menu()

  def get_balance(self):
    return self.__balance

  def set_balance(self,new_value):
    if type(new_value) == int:
      self.__balance = new_value
    else:
      print('beta bahot maarenge')

  def __menu(self):
    user_input = input("""
    Hi how can I help you?
    1. Press 1 to create pin
    2. Press 2 to change pin
    3. Press 3 to check balance
    4. Press 4 to withdraw
    5. Anything else to exit
    """)
    if user_input == '1':
      self.create_pin()
    elif user_input == '2':
      self.change_pin()
    elif user_input == '3':
      self.check_balance()
    elif user_input == '4':
      self.withdraw()
    else:
      exit()

  def create_pin(self):
    user_pin = input('enter your pin')
    self.pin = user_pin

    user_balance = int(input('enter balance'))
    self.__balance = user_balance

    print('pin created successfully')

def change_pin(self):
  old_pin = input('enter old pin')

  if old_pin == self.pin:
    # let him change the pin
    new_pin = input('enter new pin')
    self.pin = new_pin
    print('pin change successful')

  else:
    print('nai karne de sakta re baba')


def check_balance(self):
  user_pin = input('enter your pin')
  if user_pin == self.pin:
    print('your balance is',self.__balace)
  else:
    print('chal nikal yaha se')

def withdraw(self):
  user_pin = input('enter the pin')
  if user_pin == self.pin:
    #allow to withdraw
    amount = int(input('enter the amount'))
    if amount <= self.__balance:
      self.__balance = self.__balance - amount
      print('withdrawl successful.balace is' , self.__balance)
    else:
      print('chal garib')
  else:
     print('sale chor')

# %%
c1 = Atm()
# Out:
# 140489899734992

# %%
c2 = Atm()
# Out:
# 140489899731344

# %%
c3 = Atm()
# Out:
# 140489899729232

# %%
c1.cid
# Out:
# 1

# %%
c2.cid
# Out:
# 1

# %% [markdown]
# # Static variable -
# class ka variable hota hai
#
# instance variable object ka hota hai
#
# degree - static (uniqe)
#
# student name - instance variable

# %%
class Atm:

  counter =  1
  #constructor(special function) -> superpower ->
  def __init__(self):
    print(id(self))
    self.pin = ''
    self.__balance = 0
    self.cid = Atm.counter
    self.counter = Atm.counter + 1
    #self.menu()

  def get_balance(self):
    return self.__balance

  def set_balance(self,new_value):
    if type(new_value) == int:
      self.__balance = new_value
    else:
      print('beta bahot maarenge')

  def __menu(self):
    user_input = input("""
    Hi how can I help you?
    1. Press 1 to create pin
    2. Press 2 to change pin
    3. Press 3 to check balance
    4. Press 4 to withdraw
    5. Anything else to exit
    """)
    if user_input == '1':
      self.create_pin()
    elif user_input == '2':
      self.change_pin()
    elif user_input == '3':
      self.check_balance()
    elif user_input == '4':
      self.withdraw()
    else:
      exit()

  def create_pin(self):
    user_pin = input('enter your pin')
    self.pin = user_pin

    user_balance = int(input('enter balance'))
    self.__balance = user_balance

    print('pin created successfully')

def change_pin(self):
  old_pin = input('enter old pin')

  if old_pin == self.pin:
    # let him change the pin
    new_pin = input('enter new pin')
    self.pin = new_pin
    print('pin change successful')

  else:
    print('nai karne de sakta re baba')


def check_balance(self):
  user_pin = input('enter your pin')
  if user_pin == self.pin:
    print('your balance is',self.__balace)
  else:
    print('chal nikal yaha se')

def withdraw(self):
  user_pin = input('enter the pin')
  if user_pin == self.pin:
    #allow to withdraw
    amount = int(input('enter the amount'))
    if amount <= self.__balance:
      self.__balance = self.__balance - amount
      print('withdrawl successful.balace is' , self.__balance)
    else:
      print('chal garib')
  else:
     print('sale chor')

# %%
c1 = Atm()

# %%
c2 = Atm()

# %%
c3 = Atm()

# %%
c1.cid

# %%
c2.cid

# %%
c3.cid

# %%
Atm.counter

# %%
class Atm:

  __counter =  1
  #constructor(special function) -> superpower ->
  def __init__(self):
    print(id(self))
    self.pin = ''
    self.__balance = 0
    self.cid = Atm.__counter
    self.counter = Atm.__counter + 1
    #self.menu()

  #utility functions
  @staticmethod
  def get_counter():
    return Atm.__counter

  def get_balance(self):
    return self.__balance

  def set_balance(self,new_value):
    if type(new_value) == int:
      self.__balance = new_value
    else:
      print('beta bahot maarenge')

  def __menu(self):
    user_input = input("""
    Hi how can I help you?
    1. Press 1 to create pin
    2. Press 2 to change pin
    3. Press 3 to check balance
    4. Press 4 to withdraw
    5. Anything else to exit
    """)
    if user_input == '1':
      self.create_pin()
    elif user_input == '2':
      self.change_pin()
    elif user_input == '3':
      self.check_balance()
    elif user_input == '4':
      self.withdraw()
    else:
      exit()

  def create_pin(self):
    user_pin = input('enter your pin')
    self.pin = user_pin

    user_balance = int(input('enter balance'))
    self.__balance = user_balance

    print('pin created successfully')

  def change_pin(self):
    old_pin = input('enter old pin')

    if old_pin == self.pin:
      # let him change the pin
      new_pin = input('enter new pin')
      self.pin = new_pin
      print('pin change successful')

    else:
      print('nai karne de sakta re baba')


  def check_balance(self):
    user_pin = input('enter your pin')
    if user_pin == self.pin:
      print('your balance is',self.__balance)
    else:
      print('chal nikal yaha se')

  def withdraw(self):
    user_pin = input('enter the pin')
    if user_pin == self.pin:
      #allow to withdraw
      amount = int(input('enter the amount'))
      if amount <= self.__balance:
        self.__balance = self.__balance - amount
        print('withdrawl successful.balace is' , self.__balance)
      else:
        print('chal garib')
    else:
       print('sale chor')

# %%
c1 = Atm()
# Out:
# 140489900001328

# %%
Atm.get_counter()
# Out:
# 1
